# %%
import pandas as pd
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import os
import tensorflow as tf
from keras import Sequential
from keras.layers import Dense
from keras.layers import LSTM, GRU
from keras.layers import Activation
from keras.layers import Dropout
import pickle
import warnings
warnings.filterwarnings("ignore")
import logging
logging.getLogger('tensorflow').setLevel(logging.ERROR)

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Wed Dec  6 19:41:37 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.103                Driver Version: 537.13       CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 3050 ...    On  | 00000000:01:00.0  On |                  N/A |
# | N/A   54C    P8               8W /  95W |   3840MiB /  4096MiB |      4%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A     51753      C   /python3.11                               N/A      |
# +---------------------------------------------------------------------------------------+

# %%
subjectList = pd.read_csv('participantID1.csv', header=None) # import the number participant IDs without the header
numSubjects = subjectList.count()[0]

subjectAlias = np.linspace(1,numSubjects,numSubjects).tolist()
outerSubjectAlias = subjectAlias
trialNames = ['NN','YN','NY','YY'] # NN = NNL + NNH, YN = YNL + YNH, NY = NYL + NHH, YY = YYL + YYH

# %%
with open('trajectoryDataFrame_win10.pkl', 'rb') as file:
    # Call load method to deserialze
    trajectoryDataFrame = pickle.load(file)
with open('outputDataFrame_win10.pkl', 'rb') as file:
    # Call load method to deserialze
    outputDataFrame = pickle.load(file)

# %%
subjectList = pd.read_csv('participantID1.csv', header=None) # import the number participant IDs without the header
numSubjects = subjectList.count()[0]

subjectAlias = np.linspace(1,numSubjects,numSubjects).tolist()
outerSubjectAlias = subjectAlias
trialNames = ['NN','YN','NY','YY'] # NN = NNL + NNH, YN = YNL + YNH, NY = NYL + NHH, YY = YYL + YYH

# %%
# dropoutRate,LSTM1, LSTM2,numDenseLayers,features,seq_length, numClasses

parameterSpace = []

# Full parameter set
dropOutRates = 0.3
firstLSTMNodes = 128
secondLSTMNodes = 64
numDenseLayers = 2
miniBatch = 64
numEpochs = 100
featureCombo = [['speed','thetaDot']]
#featureCombo = [['speed','thetaDot','cumulativeSum','height']]

# %%
def assignUserOutput(dataFrameData, requiredSubjects):
    requiredData = dataFrameData.loc[requiredSubjects].to_numpy()
    return requiredData

def assignUserTraj(dataFrameData, requiredSubjects, featureCombo, requiredFeatureCombo):
    requiredData = np.array([])
    for i in range(len(trajectoryDataFrame)):
        temp = dataFrameData[i].loc[requiredSubjects,featureCombo[requiredFeatureCombo]].to_numpy()
        temp = temp.reshape(temp.shape[0],1,temp.shape[1])
        if i == 0:
            requiredData = temp
        if i != 0 :
            requiredData = np.append(requiredData,temp, axis=1)
    return requiredData


def lstmModel(dropoutRate, LSTM1, LSTM2, numDenseLayers, features, seq_length, numClasses):
    init_learning_rate = 0.0001
    model = Sequential()
    #model.add(GaussianNoise(0.03,input_shape=(seq_length,features)))
    model.add(LSTM(LSTM1,input_shape=(seq_length,features),return_sequences=True)) # True = many to many
    model.add(LSTM(LSTM2,input_shape=(seq_length,features),return_sequences=False)) # True = many to many
    #model.add(LSTM(LSTM1,input_shape=(seq_length,features),return_sequences=False)) # True = many to many
    model.add(Dropout(0.1))
    model.add(Dense(16, activation='LeakyReLU'))
    model.add(Dropout(0.1))
    model.add(Dense(16, activation='tanh'))
    model.add(Dropout(0.1))
    model.add(Dense(16, activation='LeakyReLU'))
    model.add(Dropout(0.1))
    model.add(Dense(16, activation='tanh'))
    model.add(Dense(numClasses,kernel_initializer='normal',activation='softmax'))
    #optimizer = tf.keras.optimizers.Adam(learning_rate=init_learning_rate, weight_decay=decay_rate)
    optimizer = tf.keras.optimizers.Adam(learning_rate=init_learning_rate)
    #model.compile(loss='categorical_crossentropy',optimizer =optimizer,metrics=['accuracy'])
    #model.compile(loss='binary_crossentropy',optimizer =optimizer,metrics=['accuracy'])  
    model.compile(loss='BinaryCrossentropy',optimizer =optimizer,metrics=['accuracy'])
    return model

# %%
trainFraction = 0.9

numTrainData = int(trainFraction*len(outerSubjectAlias))
numTestData = len(outerSubjectAlias) - numTrainData
trainSubjects = outerSubjectAlias[0:numTrainData]
testSubjects = outerSubjectAlias[len(trainSubjects):len(outerSubjectAlias)]



trainTrajData = assignUserTraj(trajectoryDataFrame,trainSubjects, featureCombo, 0)
trainOutputData = assignUserOutput(outputDataFrame,trainSubjects)

testTrajData = assignUserTraj(trajectoryDataFrame,testSubjects, featureCombo, 0)
testOutputData = assignUserOutput(outputDataFrame,testSubjects)

features = trainTrajData.shape[2]
seq_length = trainTrajData.shape[1]
numClasses = trainOutputData.shape[1]

# %%
mlModel = lstmModel(dropOutRates, firstLSTMNodes, secondLSTMNodes, numDenseLayers, features, seq_length, numClasses)
history = mlModel.fit(trainTrajData,trainOutputData,epochs=200,batch_size=128,validation_data=(testTrajData, testOutputData),verbose=1)
# Out:
# Epoch 1/200
# 32/32 [==============================] - 7s 80ms/step - loss: 0.6870 - accuracy: 0.2183 - val_loss: 0.6784 - val_accuracy: 0.1672
# Epoch 2/200
# 32/32 [==============================] - 2s 54ms/step - loss: 0.6704 - accuracy: 0.2254 - val_loss: 0.6587 - val_accuracy: 0.1906
# Epoch 3/200
# 32/32 [==============================] - 2s 57ms/step - loss: 0.6505 - accuracy: 0.2603 - val_loss: 0.6369 - val_accuracy: 0.2508
# Epoch 4/200
# 32/32 [==============================] - 2s 62ms/step - loss: 0.6317 - accuracy: 0.2829 - val_loss: 0.6182 - val_accuracy: 0.2274
# Epoch 5/200
# 32/32 [==============================] - 2s 63ms/step - loss: 0.6153 - accuracy: 0.2933 - val_loss: 0.6043 - val_accuracy: 0.2274
# Epoch 6/200
# 32/32 [==============================] - 2s 57ms/step - loss: 0.6037 - accuracy: 0.2952 - val_loss: 0.5937 - val_accuracy: 0.2274
# Epoch 7/200
# 32/32 [==============================] - 2s 64ms/step - loss: 0.5939 - accuracy: 0.3065 - val_loss: 0.5855 - val_accuracy: 0.2274
# Epoch 8/200
# 32/32 [==============================] - 2s 62ms/step - loss: 0.5863 - accuracy: 0.3041 - val_loss: 0.5791 - val_accuracy: 0.2274
# Epoch 9/200
# 32/32 [==============================] - 2s 60ms/step - loss: 0.5803 - accuracy: 0.3085 - val_loss: 0.5741 - val_accuracy: 0.2274
# Epoch 10/200
# 32/32 [==============================] - 2s 53ms/step - loss: 0.5751 - accuracy: 0.3092 - val_loss: 0.5702 - val_accuracy: 0.2274
# Epoch 11/200
# 32/32 [==============================] - 1s 41ms/step - loss: 0.5706 - accuracy: 0.3107 - val_loss: 0.5671 - val_accuracy: 0.2274
# Epoch 12/200
# 32/32 [==============================] - 1s 43ms/step - loss: 0.5678 - accuracy: 0.3117 - val_loss: 0.5648 - val_accuracy: 0.2274
# Epoch 13/200
# 32/32 [==============================] - 1s 44ms/step - loss: 0.5652 - accuracy: 0.3088 - val_loss: 0.5629 - val_accuracy: 0.2274
# Epoch 14/200
# 32/32 [==============================] - 1s 45ms/step - loss: 0.5630 - accuracy: 0.3117 - val_loss: 0.5612 - val_accuracy: 0.2274
# Epoch 15/200
# 32/32 [==============================] - 1s 44ms/step - loss: 0.5614 - accuracy: 0.3132 - val_loss: 0.5601 - val_accuracy: 0.2274
# Epoch 16/200
# 32/32 [==============================] - 1s 45ms/step - loss: 0.5599 - accuracy: 0.3144 - val_loss: 0.5590 - val_accuracy: 0.2274
# Epoch 17/200
# 32/32 [==============================] - 1s 45ms/step - loss: 0.5589 - accuracy: 0.3127 - val_loss: 0.5583 - val_accuracy: 0.2274
# Epoch 18/200
# 32/32 [==============================] - 2s 47ms/step - loss: 0.5581 - accuracy: 0.3127 - val_loss: 0.5575 - val_accuracy: 0.2274
# Epoch 19/200
# 32/32 [==============================] - 1s 46ms/step - loss: 0.5573 - accuracy: 0.3115 - val_loss: 0.5572 - val_accuracy: 0.2274
# Epoch 20/200
# 32/32 [==============================] - 2s 47ms/step - loss: 0.5567 - accuracy: 0.3122 - val_loss: 0.5568 - val_accuracy: 0.2274
# Epoch 21/200
# 32/32 [==============================] - 1s 46ms/step - loss: 0.5561 - accuracy: 0.3107 - val_loss: 0.5564 - val_accuracy: 0.2274
# Epoch 22/200
# 32/32 [==============================] - 1s 45ms/step - loss: 0.5557 - accuracy: 0.3115 - val_loss: 0.5562 - val_accuracy: 0.2274
# Epoch 23/200
# 32/32 [==============================] - 1s 44ms/step - loss: 0.5553 - accuracy: 0.3132 - val_loss: 0.5561 - val_accuracy: 0.2274
# Epoch 24/200
# 32/32 [==============================] - 1s 44ms/step - loss: 0.5552 - accuracy: 0.3112 - val_loss: 0.5559 - val_accuracy: 0.2274
# Epoch 25/200
# 32/32 [==============================] - 1s 45ms/step - loss: 0.5551 - accuracy: 0.3115 - val_loss: 0.5556 - val_accuracy: 0.2274
# Epoch 26/200
# 32/32 [==============================] - 1s 46ms/step - loss: 0.5548 - accuracy: 0.3112 - val_loss: 0.5556 - val_accuracy: 0.2274
# Epoch 27/200
# 32/32 [==============================] - 2s 48ms/step - loss: 0.5547 - accuracy: 0.3119 - val_loss: 0.5557 - val_accuracy: 0.2274
# Epoch 28/200
# 32/32 [==============================] - 1s 47ms/step - loss: 0.5543 - accuracy: 0.3137 - val_loss: 0.5556 - val_accuracy: 0.2274
# Epoch 29/200
# 32/32 [==============================] - 1s 46ms/step - loss: 0.5545 - accuracy: 0.3127 - val_loss: 0.5555 - val_accuracy: 0.2274
# Epoch 30/200
# 32/32 [==============================] - 1s 45ms/step - loss: 0.5544 - accuracy: 0.3092 - val_loss: 0.5555 - val_accuracy: 0.2274
# Epoch 31/200
# 32/32 [==============================] - 1s 45ms/step - loss: 0.5543 - accuracy: 0.3144 - val_loss: 0.5555 - val_accuracy: 0.2274
# Epoch 32/200
# 32/32 [==============================] - 2s 48ms/step - loss: 0.5543 - accuracy: 0.3174 - val_loss: 0.5557 - val_accuracy: 0.2274
# Epoch 33/200
# 32/32 [==============================] - 1s 46ms/step - loss: 0.5542 - accuracy: 0.3112 - val_loss: 0.5555 - val_accuracy: 0.2274
# Epoch 34/200
# 32/32 [==============================] - 1s 44ms/step - loss: 0.5542 - accuracy: 0.3112 - val_loss: 0.5555 - val_accuracy: 0.2274
# Epoch 35/200
# 32/32 [==============================] - 1s 43ms/step - loss: 0.5541 - accuracy: 0.3144 - val_loss: 0.5556 - val_accuracy: 0.2274
# Epoch 36/200
# 32/32 [==============================] - 1s 44ms/step - loss: 0.5541 - accuracy: 0.3147 - val_loss: 0.5556 - val_accuracy: 0.2274
# Epoch 37/200
# 32/32 [==============================] - 1s 42ms/step - loss: 0.5542 - accuracy: 0.3105 - val_loss: 0.5556 - val_accuracy: 0.2274
# Epoch 38/200
# 32/32 [==============================] - 1s 47ms/step - loss: 0.5542 - accuracy: 0.3142 - val_loss: 0.5557 - val_accuracy: 0.2274
# Epoch 39/200
# 32/32 [==============================] - 1s 47ms/step - loss: 0.5543 - accuracy: 0.3095 - val_loss: 0.5556 - val_accuracy: 0.2274
# Epoch 40/200
# 32/32 [==============================] - 1s 47ms/step - loss: 0.5541 - accuracy: 0.3154 - val_loss: 0.5555 - val_accuracy: 0.2274
# Epoch 41/200
# 32/32 [==============================] - 1s 45ms/step - loss: 0.5539 - accuracy: 0.3156 - val_loss: 0.5554 - val_accuracy: 0.2274
# Epoch 42/200
# 32/32 [==============================] - 1s 46ms/step - loss: 0.5540 - accuracy: 0.3132 - val_loss: 0.5556 - val_accuracy: 0.2274
# Epoch 43/200
# 32/32 [==============================] - 2s 49ms/step - loss: 0.5539 - accuracy: 0.3156 - val_loss: 0.5557 - val_accuracy: 0.2274
# Epoch 44/200
# 32/32 [==============================] - 1s 44ms/step - loss: 0.5539 - accuracy: 0.3105 - val_loss: 0.5556 - val_accuracy: 0.2274
# Epoch 45/200
# 32/32 [==============================] - 2s 48ms/step - loss: 0.5540 - accuracy: 0.3159 - val_loss: 0.5556 - val_accuracy: 0.2274
# Epoch 46/200
# 32/32 [==============================] - 2s 47ms/step - loss: 0.5540 - accuracy: 0.3090 - val_loss: 0.5556 - val_accuracy: 0.2274
# Epoch 47/200
# 32/32 [==============================] - 1s 45ms/step - loss: 0.5538 - accuracy: 0.3117 - val_loss: 0.5555 - val_accuracy: 0.2274
# Epoch 48/200
# 32/32 [==============================] - 2s 47ms/step - loss: 0.5539 - accuracy: 0.3127 - val_loss: 0.5555 - val_accuracy: 0.2274
# Epoch 49/200
# 32/32 [==============================] - 1s 44ms/step - loss: 0.5540 - accuracy: 0.3142 - val_loss: 0.5555 - val_accuracy: 0.2274
# Epoch 50/200
# 32/32 [==============================] - 1s 46ms/step - loss: 0.5540 - accuracy: 0.3159 - val_loss: 0.5555 - val_accuracy: 0.2274
# Epoch 51/200
# 32/32 [==============================] - 1s 45ms/step - loss: 0.5539 - accuracy: 0.3119 - val_loss: 0.5557 - val_accuracy: 0.2274
# Epoch 52/200
# 32/32 [==============================] - 1s 44ms/step - loss: 0.5540 - accuracy: 0.3115 - val_loss: 0.5557 - val_accuracy: 0.2274
# Epoch 53/200
# 32/32 [==============================] - 3s 81ms/step - loss: 0.5539 - accuracy: 0.3147 - val_loss: 0.5558 - val_accuracy: 0.2274
# Epoch 54/200
# 32/32 [==============================] - 3s 105ms/step - loss: 0.5539 - accuracy: 0.3129 - val_loss: 0.5557 - val_accuracy: 0.2274
# Epoch 55/200
# 32/32 [==============================] - 3s 106ms/step - loss: 0.5539 - accuracy: 0.3078 - val_loss: 0.5556 - val_accuracy: 0.2274
# Epoch 56/200
# 32/32 [==============================] - 3s 108ms/step - loss: 0.5537 - accuracy: 0.3124 - val_loss: 0.5554 - val_accuracy: 0.2274
# Epoch 57/200
# 32/32 [==============================] - 3s 107ms/step - loss: 0.5539 - accuracy: 0.3124 - val_loss: 0.5556 - val_accuracy: 0.2274
# Epoch 58/200
# 32/32 [==============================] - 3s 107ms/step - loss: 0.5540 - accuracy: 0.3112 - val_loss: 0.5555 - val_accuracy: 0.2274
# Epoch 59/200
# 32/32 [==============================] - 3s 108ms/step - loss: 0.5539 - accuracy: 0.3117 - val_loss: 0.5555 - val_accuracy: 0.2274
# Epoch 60/200
# 32/32 [==============================] - 3s 105ms/step - loss: 0.5540 - accuracy: 0.3083 - val_loss: 0.5555 - val_accuracy: 0.2274
# Epoch 61/200
# 32/32 [==============================] - 3s 105ms/step - loss: 0.5539 - accuracy: 0.3100 - val_loss: 0.5555 - val_accuracy: 0.2274
# Epoch 62/200
# 32/32 [==============================] - 3s 103ms/step - loss: 0.5539 - accuracy: 0.3139 - val_loss: 0.5556 - val_accuracy: 0.2274
# Epoch 63/200
# 32/32 [==============================] - 3s 104ms/step - loss: 0.5539 - accuracy: 0.3134 - val_loss: 0.5555 - val_accuracy: 0.2274
# Epoch 64/200
# 32/32 [==============================] - 3s 107ms/step - loss: 0.5538 - accuracy: 0.3119 - val_loss: 0.5556 - val_accuracy: 0.2274
# Epoch 65/200
# 32/32 [==============================] - 3s 105ms/step - loss: 0.5537 - accuracy: 0.3132 - val_loss: 0.5555 - val_accuracy: 0.2274
# Epoch 66/200
# 32/32 [==============================] - 3s 104ms/step - loss: 0.5539 - accuracy: 0.3112 - val_loss: 0.5555 - val_accuracy: 0.2274
# Epoch 67/200
# 32/32 [==============================] - 3s 104ms/step - loss: 0.5537 - accuracy: 0.3132 - val_loss: 0.5555 - val_accuracy: 0.2274
# Epoch 68/200
# 32/32 [==============================] - 3s 105ms/step - loss: 0.5538 - accuracy: 0.3132 - val_loss: 0.5556 - val_accuracy: 0.2274
# Epoch 69/200
# 32/32 [==============================] - 3s 107ms/step - loss: 0.5539 - accuracy: 0.3119 - val_loss: 0.5555 - val_accuracy: 0.2274
# Epoch 70/200
# 32/32 [==============================] - 3s 105ms/step - loss: 0.5539 - accuracy: 0.3122 - val_loss: 0.5555 - val_accuracy: 0.2274
# Epoch 71/200
# 32/32 [==============================] - 3s 106ms/step - loss: 0.5538 - accuracy: 0.3144 - val_loss: 0.5556 - val_accuracy: 0.2274
# Epoch 72/200
# 32/32 [==============================] - 3s 106ms/step - loss: 0.5538 - accuracy: 0.3112 - val_loss: 0.5554 - val_accuracy: 0.2274
# Epoch 73/200
# 32/32 [==============================] - 3s 105ms/step - loss: 0.5538 - accuracy: 0.3122 - val_loss: 0.5555 - val_accuracy: 0.2274
# Epoch 74/200
# 32/32 [==============================] - 3s 108ms/step - loss: 0.5538 - accuracy: 0.3137 - val_loss: 0.5555 - val_accuracy: 0.2274
# Epoch 75/200
# 32/32 [==============================] - 3s 105ms/step - loss: 0.5537 - accuracy: 0.3129 - val_loss: 0.5555 - val_accuracy: 0.2274
# Epoch 76/200
# 32/32 [==============================] - 3s 105ms/step - loss: 0.5536 - accuracy: 0.3119 - val_loss: 0.5555 - val_accuracy: 0.2274
# Epoch 77/200
# 32/32 [==============================] - 3s 105ms/step - loss: 0.5537 - accuracy: 0.3112 - val_loss: 0.5554 - val_accuracy: 0.2274
# Epoch 78/200
# 32/32 [==============================] - 3s 106ms/step - loss: 0.5538 - accuracy: 0.3127 - val_loss: 0.5555 - val_accuracy: 0.2274
# Epoch 79/200
# 32/32 [==============================] - 4s 111ms/step - loss: 0.5538 - accuracy: 0.3129 - val_loss: 0.5554 - val_accuracy: 0.2274
# Epoch 80/200
# 32/32 [==============================] - 3s 105ms/step - loss: 0.5537 - accuracy: 0.3112 - val_loss: 0.5554 - val_accuracy: 0.2274
# Epoch 81/200
# 32/32 [==============================] - 3s 102ms/step - loss: 0.5537 - accuracy: 0.3164 - val_loss: 0.5555 - val_accuracy: 0.2274
# Epoch 82/200
# 32/32 [==============================] - 3s 106ms/step - loss: 0.5537 - accuracy: 0.3115 - val_loss: 0.5556 - val_accuracy: 0.2274
# Epoch 83/200
# 32/32 [==============================] - 3s 107ms/step - loss: 0.5537 - accuracy: 0.3085 - val_loss: 0.5554 - val_accuracy: 0.2274
# Epoch 84/200
# 32/32 [==============================] - 3s 107ms/step - loss: 0.5536 - accuracy: 0.3129 - val_loss: 0.5555 - val_accuracy: 0.2274
# Epoch 85/200
# 32/32 [==============================] - 3s 105ms/step - loss: 0.5538 - accuracy: 0.3144 - val_loss: 0.5555 - val_accuracy: 0.2274
# Epoch 86/200
# 32/32 [==============================] - 3s 106ms/step - loss: 0.5537 - accuracy: 0.3110 - val_loss: 0.5554 - val_accuracy: 0.2274
# Epoch 87/200
# 32/32 [==============================] - 3s 104ms/step - loss: 0.5537 - accuracy: 0.3092 - val_loss: 0.5554 - val_accuracy: 0.2274
# Epoch 88/200
# 32/32 [==============================] - 3s 103ms/step - loss: 0.5537 - accuracy: 0.3092 - val_loss: 0.5555 - val_accuracy: 0.2274
# Epoch 89/200
# 32/32 [==============================] - 3s 105ms/step - loss: 0.5538 - accuracy: 0.3124 - val_loss: 0.5555 - val_accuracy: 0.2274
# Epoch 90/200
# 32/32 [==============================] - 3s 106ms/step - loss: 0.5537 - accuracy: 0.3122 - val_loss: 0.5554 - val_accuracy: 0.2274
# Epoch 91/200
# 32/32 [==============================] - 3s 107ms/step - loss: 0.5537 - accuracy: 0.3124 - val_loss: 0.5554 - val_accuracy: 0.2274
# Epoch 92/200
# 32/32 [==============================] - 3s 105ms/step - loss: 0.5537 - accuracy: 0.3122 - val_loss: 0.5554 - val_accuracy: 0.2274
# Epoch 93/200
# 32/32 [==============================] - 3s 105ms/step - loss: 0.5538 - accuracy: 0.3144 - val_loss: 0.5554 - val_accuracy: 0.2274
# Epoch 94/200
# 32/32 [==============================] - 3s 104ms/step - loss: 0.5537 - accuracy: 0.3110 - val_loss: 0.5553 - val_accuracy: 0.2274
# Epoch 95/200
# 32/32 [==============================] - 3s 106ms/step - loss: 0.5537 - accuracy: 0.3144 - val_loss: 0.5555 - val_accuracy: 0.2274
# Epoch 96/200
# 32/32 [==============================] - 3s 107ms/step - loss: 0.5537 - accuracy: 0.3134 - val_loss: 0.5554 - val_accuracy: 0.2274
# Epoch 97/200
# 32/32 [==============================] - 3s 105ms/step - loss: 0.5536 - accuracy: 0.3129 - val_loss: 0.5554 - val_accuracy: 0.2274
# Epoch 98/200
# 32/32 [==============================] - 3s 107ms/step - loss: 0.5536 - accuracy: 0.3127 - val_loss: 0.5555 - val_accuracy: 0.2274
# Epoch 99/200
# 32/32 [==============================] - 3s 106ms/step - loss: 0.5536 - accuracy: 0.3142 - val_loss: 0.5555 - val_accuracy: 0.2274
# Epoch 100/200
# 32/32 [==============================] - 3s 105ms/step - loss: 0.5536 - accuracy: 0.3132 - val_loss: 0.5554 - val_accuracy: 0.2274
# Epoch 101/200
# 32/32 [==============================] - 3s 105ms/step - loss: 0.5537 - accuracy: 0.3119 - val_loss: 0.5555 - val_accuracy: 0.2274
# Epoch 102/200
# 32/32 [==============================] - 3s 104ms/step - loss: 0.5537 - accuracy: 0.3090 - val_loss: 0.5552 - val_accuracy: 0.2274
# Epoch 103/200
# 32/32 [==============================] - 3s 105ms/step - loss: 0.5536 - accuracy: 0.3122 - val_loss: 0.5555 - val_accuracy: 0.2274
# Epoch 104/200
# 32/32 [==============================] - 3s 108ms/step - loss: 0.5537 - accuracy: 0.3112 - val_loss: 0.5555 - val_accuracy: 0.2274
# Epoch 105/200
# 32/32 [==============================] - 4s 116ms/step - loss: 0.5538 - accuracy: 0.3132 - val_loss: 0.5553 - val_accuracy: 0.2274
# Epoch 106/200
# 32/32 [==============================] - 3s 104ms/step - loss: 0.5537 - accuracy: 0.3124 - val_loss: 0.5554 - val_accuracy: 0.2274
# Epoch 107/200
# 32/32 [==============================] - 3s 105ms/step - loss: 0.5537 - accuracy: 0.3132 - val_loss: 0.5555 - val_accuracy: 0.2274
# Epoch 108/200
# 32/32 [==============================] - 3s 104ms/step - loss: 0.5536 - accuracy: 0.3119 - val_loss: 0.5555 - val_accuracy: 0.2274
# Epoch 109/200
# 32/32 [==============================] - 3s 105ms/step - loss: 0.5537 - accuracy: 0.3127 - val_loss: 0.5554 - val_accuracy: 0.2274
# Epoch 110/200
# 32/32 [==============================] - 3s 105ms/step - loss: 0.5537 - accuracy: 0.3137 - val_loss: 0.5553 - val_accuracy: 0.2274
# Epoch 111/200
# 32/32 [==============================] - 3s 105ms/step - loss: 0.5536 - accuracy: 0.3129 - val_loss: 0.5554 - val_accuracy: 0.2274
# Epoch 112/200
# 32/32 [==============================] - 3s 106ms/step - loss: 0.5536 - accuracy: 0.3122 - val_loss: 0.5555 - val_accuracy: 0.2274
# Epoch 113/200
# 32/32 [==============================] - 3s 104ms/step - loss: 0.5536 - accuracy: 0.3132 - val_loss: 0.5553 - val_accuracy: 0.2274
# Epoch 114/200
# 32/32 [==============================] - 3s 106ms/step - loss: 0.5536 - accuracy: 0.3137 - val_loss: 0.5555 - val_accuracy: 0.2274
# Epoch 115/200
# 32/32 [==============================] - 3s 106ms/step - loss: 0.5537 - accuracy: 0.3134 - val_loss: 0.5555 - val_accuracy: 0.2274
# Epoch 116/200
# 32/32 [==============================] - 3s 104ms/step - loss: 0.5536 - accuracy: 0.3132 - val_loss: 0.5553 - val_accuracy: 0.2274
# Epoch 117/200
# 32/32 [==============================] - 3s 105ms/step - loss: 0.5536 - accuracy: 0.3127 - val_loss: 0.5556 - val_accuracy: 0.2274
# Epoch 118/200
# 32/32 [==============================] - 3s 106ms/step - loss: 0.5537 - accuracy: 0.3132 - val_loss: 0.5554 - val_accuracy: 0.2274
# Epoch 119/200
# 32/32 [==============================] - 3s 105ms/step - loss: 0.5535 - accuracy: 0.3129 - val_loss: 0.5552 - val_accuracy: 0.2274
# Epoch 120/200
# 32/32 [==============================] - 3s 106ms/step - loss: 0.5536 - accuracy: 0.3124 - val_loss: 0.5554 - val_accuracy: 0.2274
# Epoch 121/200
# 32/32 [==============================] - 3s 105ms/step - loss: 0.5535 - accuracy: 0.3137 - val_loss: 0.5553 - val_accuracy: 0.2274
# Epoch 122/200
# 32/32 [==============================] - 3s 106ms/step - loss: 0.5536 - accuracy: 0.3110 - val_loss: 0.5553 - val_accuracy: 0.2274
# Epoch 123/200
# 32/32 [==============================] - 3s 105ms/step - loss: 0.5535 - accuracy: 0.3129 - val_loss: 0.5554 - val_accuracy: 0.2274
# Epoch 124/200
# 32/32 [==============================] - 3s 106ms/step - loss: 0.5536 - accuracy: 0.3139 - val_loss: 0.5554 - val_accuracy: 0.2274
# Epoch 125/200
# 32/32 [==============================] - 3s 105ms/step - loss: 0.5535 - accuracy: 0.3132 - val_loss: 0.5553 - val_accuracy: 0.2274
# Epoch 126/200
# 32/32 [==============================] - 3s 105ms/step - loss: 0.5535 - accuracy: 0.3124 - val_loss: 0.5556 - val_accuracy: 0.2274
# Epoch 127/200
# 32/32 [==============================] - 3s 105ms/step - loss: 0.5536 - accuracy: 0.3119 - val_loss: 0.5554 - val_accuracy: 0.2274
# Epoch 128/200
# 32/32 [==============================] - 3s 105ms/step - loss: 0.5537 - accuracy: 0.3115 - val_loss: 0.5553 - val_accuracy: 0.2274
# Epoch 129/200
# 32/32 [==============================] - 3s 106ms/step - loss: 0.5537 - accuracy: 0.3122 - val_loss: 0.5553 - val_accuracy: 0.2274
# Epoch 130/200
# 32/32 [==============================] - 3s 104ms/step - loss: 0.5536 - accuracy: 0.3134 - val_loss: 0.5552 - val_accuracy: 0.2274
# Epoch 131/200
# 32/32 [==============================] - 3s 107ms/step - loss: 0.5536 - accuracy: 0.3134 - val_loss: 0.5554 - val_accuracy: 0.2274
# Epoch 132/200
# 32/32 [==============================] - 3s 105ms/step - loss: 0.5536 - accuracy: 0.3127 - val_loss: 0.5555 - val_accuracy: 0.2274
# Epoch 133/200
# 32/32 [==============================] - 3s 105ms/step - loss: 0.5536 - accuracy: 0.3132 - val_loss: 0.5553 - val_accuracy: 0.2274
# Epoch 134/200
# 32/32 [==============================] - 3s 104ms/step - loss: 0.5536 - accuracy: 0.3122 - val_loss: 0.5553 - val_accuracy: 0.2274
# Epoch 135/200
# 32/32 [==============================] - 3s 106ms/step - loss: 0.5536 - accuracy: 0.3124 - val_loss: 0.5556 - val_accuracy: 0.2274
# Epoch 136/200
# 32/32 [==============================] - 3s 104ms/step - loss: 0.5536 - accuracy: 0.3124 - val_loss: 0.5554 - val_accuracy: 0.2274
# Epoch 137/200
# 32/32 [==============================] - 3s 106ms/step - loss: 0.5536 - accuracy: 0.3122 - val_loss: 0.5554 - val_accuracy: 0.2274
# Epoch 138/200
# 32/32 [==============================] - 3s 104ms/step - loss: 0.5536 - accuracy: 0.3119 - val_loss: 0.5554 - val_accuracy: 0.2274
# Epoch 139/200
# 32/32 [==============================] - 3s 105ms/step - loss: 0.5536 - accuracy: 0.3127 - val_loss: 0.5553 - val_accuracy: 0.2274
# Epoch 140/200
# 32/32 [==============================] - 3s 105ms/step - loss: 0.5535 - accuracy: 0.3127 - val_loss: 0.5552 - val_accuracy: 0.2274
# Epoch 141/200
# 32/32 [==============================] - 3s 104ms/step - loss: 0.5536 - accuracy: 0.3122 - val_loss: 0.5552 - val_accuracy: 0.2274
# Epoch 142/200
# 32/32 [==============================] - 3s 104ms/step - loss: 0.5536 - accuracy: 0.3127 - val_loss: 0.5554 - val_accuracy: 0.2274
# Epoch 143/200
# 32/32 [==============================] - 3s 105ms/step - loss: 0.5536 - accuracy: 0.3139 - val_loss: 0.5554 - val_accuracy: 0.2274
# Epoch 144/200
# 32/32 [==============================] - 3s 105ms/step - loss: 0.5536 - accuracy: 0.3129 - val_loss: 0.5554 - val_accuracy: 0.2274
# Epoch 145/200
# 32/32 [==============================] - 3s 105ms/step - loss: 0.5536 - accuracy: 0.3132 - val_loss: 0.5553 - val_accuracy: 0.2274
# Epoch 146/200
# 32/32 [==============================] - 3s 105ms/step - loss: 0.5535 - accuracy: 0.3115 - val_loss: 0.5553 - val_accuracy: 0.2274
# Epoch 147/200
# 32/32 [==============================] - 3s 106ms/step - loss: 0.5535 - accuracy: 0.3134 - val_loss: 0.5554 - val_accuracy: 0.2274
# Epoch 148/200
# 32/32 [==============================] - 3s 105ms/step - loss: 0.5535 - accuracy: 0.3129 - val_loss: 0.5552 - val_accuracy: 0.2274
# Epoch 149/200
# 32/32 [==============================] - 3s 105ms/step - loss: 0.5536 - accuracy: 0.3124 - val_loss: 0.5554 - val_accuracy: 0.2274
# Epoch 150/200
# 32/32 [==============================] - 3s 104ms/step - loss: 0.5536 - accuracy: 0.3132 - val_loss: 0.5554 - val_accuracy: 0.2274
# Epoch 151/200
# 32/32 [==============================] - 3s 104ms/step - loss: 0.5535 - accuracy: 0.3134 - val_loss: 0.5554 - val_accuracy: 0.2274
# Epoch 152/200
# 32/32 [==============================] - 3s 105ms/step - loss: 0.5536 - accuracy: 0.3132 - val_loss: 0.5554 - val_accuracy: 0.2274
# Epoch 153/200
# 32/32 [==============================] - 3s 105ms/step - loss: 0.5536 - accuracy: 0.3139 - val_loss: 0.5553 - val_accuracy: 0.2274
# Epoch 154/200
# 32/32 [==============================] - 3s 106ms/step - loss: 0.5536 - accuracy: 0.3129 - val_loss: 0.5555 - val_accuracy: 0.2274
# Epoch 155/200
# 32/32 [==============================] - 3s 104ms/step - loss: 0.5536 - accuracy: 0.3119 - val_loss: 0.5553 - val_accuracy: 0.2274
# Epoch 156/200
# 32/32 [==============================] - 3s 106ms/step - loss: 0.5536 - accuracy: 0.3110 - val_loss: 0.5553 - val_accuracy: 0.2274
# Epoch 157/200
# 32/32 [==============================] - 3s 105ms/step - loss: 0.5535 - accuracy: 0.3127 - val_loss: 0.5554 - val_accuracy: 0.2274
# Epoch 158/200
# 32/32 [==============================] - 3s 106ms/step - loss: 0.5536 - accuracy: 0.3117 - val_loss: 0.5553 - val_accuracy: 0.2274
# Epoch 159/200
# 32/32 [==============================] - 4s 122ms/step - loss: 0.5536 - accuracy: 0.3127 - val_loss: 0.5554 - val_accuracy: 0.2274
# Epoch 160/200
# 32/32 [==============================] - 7s 219ms/step - loss: 0.5535 - accuracy: 0.3129 - val_loss: 0.5553 - val_accuracy: 0.2274
# Epoch 161/200
# 32/32 [==============================] - 6s 188ms/step - loss: 0.5535 - accuracy: 0.3124 - val_loss: 0.5553 - val_accuracy: 0.2274
# Epoch 162/200
# 32/32 [==============================] - 6s 194ms/step - loss: 0.5535 - accuracy: 0.3127 - val_loss: 0.5551 - val_accuracy: 0.2274
# Epoch 163/200
# 32/32 [==============================] - 6s 195ms/step - loss: 0.5536 - accuracy: 0.3122 - val_loss: 0.5553 - val_accuracy: 0.2274
# Epoch 164/200
# 32/32 [==============================] - 6s 196ms/step - loss: 0.5536 - accuracy: 0.3127 - val_loss: 0.5553 - val_accuracy: 0.2274
# Epoch 165/200
# 32/32 [==============================] - 6s 196ms/step - loss: 0.5536 - accuracy: 0.3127 - val_loss: 0.5554 - val_accuracy: 0.2274
# Epoch 166/200
# 32/32 [==============================] - 6s 195ms/step - loss: 0.5535 - accuracy: 0.3127 - val_loss: 0.5555 - val_accuracy: 0.2274
# Epoch 167/200
# 32/32 [==============================] - 6s 195ms/step - loss: 0.5536 - accuracy: 0.3117 - val_loss: 0.5553 - val_accuracy: 0.2274
# Epoch 168/200
# 32/32 [==============================] - 6s 195ms/step - loss: 0.5535 - accuracy: 0.3115 - val_loss: 0.5552 - val_accuracy: 0.2274
# Epoch 169/200
# 32/32 [==============================] - 6s 196ms/step - loss: 0.5536 - accuracy: 0.3110 - val_loss: 0.5553 - val_accuracy: 0.2274
# Epoch 170/200
# 32/32 [==============================] - 6s 197ms/step - loss: 0.5536 - accuracy: 0.3127 - val_loss: 0.5553 - val_accuracy: 0.2274
# Epoch 171/200
# 32/32 [==============================] - 6s 196ms/step - loss: 0.5535 - accuracy: 0.3117 - val_loss: 0.5554 - val_accuracy: 0.2274
# Epoch 172/200
# 32/32 [==============================] - 6s 196ms/step - loss: 0.5535 - accuracy: 0.3134 - val_loss: 0.5554 - val_accuracy: 0.2274
# Epoch 173/200
# 32/32 [==============================] - 6s 195ms/step - loss: 0.5535 - accuracy: 0.3124 - val_loss: 0.5553 - val_accuracy: 0.2274
# Epoch 174/200
# 32/32 [==============================] - 6s 196ms/step - loss: 0.5535 - accuracy: 0.3134 - val_loss: 0.5553 - val_accuracy: 0.2274
# Epoch 175/200
# 32/32 [==============================] - 6s 195ms/step - loss: 0.5535 - accuracy: 0.3124 - val_loss: 0.5553 - val_accuracy: 0.2274
# Epoch 176/200
# 32/32 [==============================] - 6s 195ms/step - loss: 0.5536 - accuracy: 0.3124 - val_loss: 0.5553 - val_accuracy: 0.2274
# Epoch 177/200
# 32/32 [==============================] - 6s 195ms/step - loss: 0.5535 - accuracy: 0.3129 - val_loss: 0.5553 - val_accuracy: 0.2274
# Epoch 178/200
# 32/32 [==============================] - 6s 196ms/step - loss: 0.5535 - accuracy: 0.3127 - val_loss: 0.5553 - val_accuracy: 0.2274
# Epoch 179/200
# 32/32 [==============================] - 6s 196ms/step - loss: 0.5535 - accuracy: 0.3129 - val_loss: 0.5554 - val_accuracy: 0.2274
# Epoch 180/200
# 32/32 [==============================] - 6s 195ms/step - loss: 0.5535 - accuracy: 0.3129 - val_loss: 0.5553 - val_accuracy: 0.2274
# Epoch 181/200
# 32/32 [==============================] - 6s 197ms/step - loss: 0.5535 - accuracy: 0.3132 - val_loss: 0.5552 - val_accuracy: 0.2274
# Epoch 182/200
# 32/32 [==============================] - 6s 196ms/step - loss: 0.5536 - accuracy: 0.3129 - val_loss: 0.5553 - val_accuracy: 0.2274
# Epoch 183/200
# 32/32 [==============================] - 6s 195ms/step - loss: 0.5535 - accuracy: 0.3122 - val_loss: 0.5552 - val_accuracy: 0.2274
# Epoch 184/200
# 32/32 [==============================] - 6s 195ms/step - loss: 0.5535 - accuracy: 0.3127 - val_loss: 0.5552 - val_accuracy: 0.2274
# Epoch 185/200
# 32/32 [==============================] - 6s 195ms/step - loss: 0.5536 - accuracy: 0.3129 - val_loss: 0.5553 - val_accuracy: 0.2274
# Epoch 186/200
# 32/32 [==============================] - 6s 197ms/step - loss: 0.5535 - accuracy: 0.3132 - val_loss: 0.5553 - val_accuracy: 0.2274
# Epoch 187/200
# 32/32 [==============================] - 6s 197ms/step - loss: 0.5536 - accuracy: 0.3129 - val_loss: 0.5553 - val_accuracy: 0.2274
# Epoch 188/200
# 32/32 [==============================] - 6s 195ms/step - loss: 0.5535 - accuracy: 0.3127 - val_loss: 0.5554 - val_accuracy: 0.2274
# Epoch 189/200
# 32/32 [==============================] - 6s 196ms/step - loss: 0.5536 - accuracy: 0.3124 - val_loss: 0.5555 - val_accuracy: 0.2274
# Epoch 190/200
# 32/32 [==============================] - 6s 195ms/step - loss: 0.5535 - accuracy: 0.3119 - val_loss: 0.5553 - val_accuracy: 0.2274
# Epoch 191/200
# 32/32 [==============================] - 6s 196ms/step - loss: 0.5535 - accuracy: 0.3122 - val_loss: 0.5553 - val_accuracy: 0.2274
# Epoch 192/200
# 32/32 [==============================] - 6s 195ms/step - loss: 0.5536 - accuracy: 0.3124 - val_loss: 0.5554 - val_accuracy: 0.2274
# Epoch 193/200
# 32/32 [==============================] - 6s 196ms/step - loss: 0.5535 - accuracy: 0.3124 - val_loss: 0.5554 - val_accuracy: 0.2274
# Epoch 194/200
# 32/32 [==============================] - 6s 197ms/step - loss: 0.5535 - accuracy: 0.3124 - val_loss: 0.5552 - val_accuracy: 0.2274
# Epoch 195/200
# 32/32 [==============================] - 6s 196ms/step - loss: 0.5535 - accuracy: 0.3127 - val_loss: 0.5551 - val_accuracy: 0.2274
# Epoch 196/200
# 32/32 [==============================] - 6s 196ms/step - loss: 0.5535 - accuracy: 0.3127 - val_loss: 0.5552 - val_accuracy: 0.2274
# Epoch 197/200
# 32/32 [==============================] - 6s 197ms/step - loss: 0.5535 - accuracy: 0.3127 - val_loss: 0.5553 - val_accuracy: 0.2274
# Epoch 198/200
# 32/32 [==============================] - 6s 196ms/step - loss: 0.5535 - accuracy: 0.3127 - val_loss: 0.5554 - val_accuracy: 0.2274
# Epoch 199/200
# 32/32 [==============================] - 6s 196ms/step - loss: 0.5535 - accuracy: 0.3129 - val_loss: 0.5552 - val_accuracy: 0.2274
# Epoch 200/200
# 32/32 [==============================] - 6s 197ms/step - loss: 0.5535 - accuracy: 0.3127 - val_loss: 0.5553 - val_accuracy: 0.2274

# %%
#Predict
y_prediction = mlModel.predict(testTrajData)
y_test = testOutputData
# Out:
# 10/10 [==============================] - 0s 40ms/step

# %%
y_prediction=np.argmax(y_prediction, axis=-1)
y_test=np.argmax(y_test, axis=-1)
#Create confusion matrix and normalizes it over predicted (columns)
result = confusion_matrix(y_test, y_prediction,normalize='pred')
ax = sns.heatmap(result, annot=True, fmt=".2f")
#ax.set_xticklabels(trialNames)
#ax.set_yticklabels(trialNames)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# %%
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.xlabel('Epoch', fontsize=24)
plt.ylabel('Accuracy', fontsize=24)
plt.tick_params(axis='both', which='major', labelsize=23)
plt.legend(fontsize=20)

# %%
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.plot(history.history['loss'], label='Training Loss')
plt.xlabel('Epoch', fontsize=24)
plt.ylabel('Loss', fontsize=24)
plt.tick_params(axis='both', which='major', labelsize=23)
plt.legend(fontsize=20)
